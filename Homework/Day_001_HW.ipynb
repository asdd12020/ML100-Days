# %% [markdown]
# HW1
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下
# 1. 你選的這組資料為何重要
# 2. 資料從何而來 (tips: 如提供者是誰、以什麼方式蒐集)
# 3. 蒐集而來的資料型態為何
# 4. 這組資料想解決的問題如何評估
#
# 選了此組資料 : https://www.kaggle.com/lava18/google-play-store-apps
#
# 1.如果之後有要開發遊戲，想要透過資料先了解 PLAY STORE內遊戲走向、熱度跟趨勢如何
#
# 2.Kaggle 用戶Lavanya Gupta，使用網頁抓取的模式蒐集(他有提到相比APP Store,Play Store的資料比較難抓取)
#
# 3.已結構化的資料檔案(.csv)
#
# 4.不同種類的遊戲，客群樣貌如何、熱度為何、收到的Review為正面還是負面的多
#
# HW2
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請
# 你思考並描述你如何規劃整體的分析/解決方案
# 1. 核心問題為何 (tips: 如何定義 提升業績 & 你的假設)
# 2. 資料從何而來 (tips: 哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 3. 蒐集而來的資料型態為何
# 4. 你要回答的問題，其如何評估 (tips: 你的假設如何驗證)
#
# 1.提升載客流量、看是否能提升業績-載客多是否營收會更多，讓營收高於支出，有盈餘跟更高的獎金
#
# 2.學生的上下課時間以及公司的上下班的時間(人流 & 車流) ，透過問卷調查以及Google map的車流量統計做分析(可運用政府開放系統抓取車流資料)
# 政府資料公開平台(站間平均行駛車速) : https://data.gov.tw/dataset/26063
#
# 3.可能為csv、json、紙本問卷資料
#
# 4.運用人流車流做出載客路線與地圖 → 依照製作地圖往人流多、比較缺車的地方進行載客，
# 且還要運用車流量資訊，製作在交通壅塞的情況下、替代道路的地圖。
# 讓自己的車隊能在同一天載到更多的客人

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    """
    請完成這個 Function 後往下執行
    """
    MSE = ((y-y_hat)**2).mean()
    return(MSE)

def mean_absolute_error(y, y_hat):
    MAE = np.fabs(y-y_hat).mean()
    return(MAE)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 218.433
# The Mean absolute error is 12.188
